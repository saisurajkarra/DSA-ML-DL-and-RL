# %%
# !pip install rasterio
# Out:
# ...
#      |████████████████████████████████| 19.3 MB 1.3 MB/s
# ...

# %%
import rasterio
import os
from rasterio.plot import show
from matplotlib import pyplot
import numpy as np
# %matplotlib inline

# Data dir
data_dir =  r"/content/drive/MyDrive/images"
for images in os.listdir(data_dir):
 
    # check if the image ends with png
    if (images.endswith(".tiff")):
        fp = os.path.join(data_dir,images)
        raster = rasterio.open(fp)
        print(raster.shape)
        show(raster)
# Out:
# (745, 747)
# /usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# (934, 1400)
# (1301, 1950)
# (720, 771)
# (1301, 1950)
# (745, 747)
# (745, 747)
# (745, 747)
# (745, 747)
# (745, 747)

# %%
import rasterio
import os
from rasterio.plot import show
from matplotlib import pyplot
import numpy as np
# %matplotlib inline

# Data dir
data_dir =  r"/content/drive/MyDrive/images"
for images in os.listdir(data_dir):
 
    # check if the image ends with png
    if (images.endswith(".tiff")):
        fp = os.path.join(data_dir,images)
        raster = rasterio.open(fp)
      
        upscale_factor = 0.5
        data = raster.read(
                out_shape=(
                    raster.count,
                    int(raster.height * upscale_factor),
                    int(raster.width * upscale_factor)
                ),
                resampling=Resampling.bilinear
            )

            # scale image transform
        transform = raster.transform * raster.transform.scale(
                (raster.width / data.shape[-1]),
                (raster.height / data.shape[-2])
            )
        image = data
        show(image[1])
        print(image.shape)
# Out:
# (12, 372, 373)
# /usr/local/lib/python3.7/dist-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# (4, 467, 700)
# (4, 650, 975)
# (4, 360, 385)
# (4, 650, 975)
# (12, 372, 373)
# (12, 372, 373)
# (12, 372, 373)
# (12, 372, 373)
# (12, 372, 373)
